# %% [markdown]
# 1. Now select the rows from 20th index till 200th index (exclusive), and columns from 2nd index till
# 15th index value.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('customer_churn-1.csv')

# %%
newdf = dataframe.iloc[20:201, 1:15]
newdf
# Out:
#      gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 20     Male              1      No         No       1           No
# 21     Male              0     Yes         No      12          Yes
# 22     Male              0      No         No       1          Yes
# 23   Female              0     Yes         No      58          Yes
# 24     Male              0     Yes        Yes      49          Yes
# ..      ...            ...     ...        ...     ...          ...
# 196    Male              0     Yes        Yes      24          Yes
# 197    Male              0      No         No      59          Yes
# 198    Male              0     Yes        Yes      72          Yes
# 199    Male              0      No        Yes       1          Yes
# 200  Female              0     Yes         No      27          Yes
#
#         MultipleLines InternetService       OnlineSecurity  \
# 20   No phone service             DSL                   No
# ...
