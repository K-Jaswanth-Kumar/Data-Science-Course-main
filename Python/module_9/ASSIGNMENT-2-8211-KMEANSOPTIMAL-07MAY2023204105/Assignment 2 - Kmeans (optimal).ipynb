# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('customers-1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

fig=plt.figure()

plt.scatter(df['Age'], df['Spending Score (1-100)'])
plt.xlabel('Age') 
plt.ylabel('Spending Score (1-100)')
plt.title('Age vs Spending Score (1-100)')
plt.show()

# %%
X1 = df[['Age' , 'Spending Score (1-100)']].iloc[: , :].values
inertia = []
for n in range(1 , 10):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300, 
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(X1)
    inertia.append(algorithm.inertia_)
# Out:
# C:\Users\saidh\anaconda3\envs\tensorflow\lib\site-packages\sklearn\cluster\_kmeans.py:828: RuntimeWarning: algorithm='elkan' doesn't make sense for a single cluster. Using 'full' instead.
#   "cluster. Using 'full' instead.", RuntimeWarning)
# C:\Users\saidh\anaconda3\envs\tensorflow\lib\site-packages\sklearn\cluster\_kmeans.py:882: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   f"KMeans is known to have a memory leak on Windows "

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 10) , inertia , 'o')
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %%
k = 5  # Number of clusters
kmeans = KMeans(n_clusters=k)

# %%
kmeans.fit(X1)
# Out:
# KMeans(n_clusters=5)

# %%
labels = algorithm.labels_
centroids = algorithm.cluster_centers_

# %%
plt.scatter(X1[:, 0], X1[:, 1], c=labels, cmap='viridis')

# plt.scatter(centroids[:, 0], centroids[:, 1], marker='x', color='red', s=100)

# Set labels and title
plt.xlabel('X')
plt.ylabel('Y')
plt.title('K-means Clustering')

# Show the plot
plt.show()
